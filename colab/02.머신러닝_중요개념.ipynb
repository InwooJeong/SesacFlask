# %% [markdown]
# # 머신러닝 장르

# %% [markdown]
# - 지도학습
# - 비지도 학습
# - 준지도 학습
# - 강화 학습

# %% [markdown]
# #알고리즘

# %% [markdown]
# ## 지도 학습 > 분류

# %% [markdown]
# - 로지스틱 회귀
# - KNN
# - 나이브베이즈
# - 결정트리
# - SVM
# - 앙상블
#   - 보팅
#   - 배깅
#     - 랜덤포레스트
#   - 부스팅
#     - XGBoost
#     - LightGBM
#     - CatBoost
#   - 스태킹(메타 학습)

# %% [markdown]
# ## 지도 학습 > 회귀

# %% [markdown]
# - 선현 회귀
# - LNN
# - Lasso
# - Ridge
# - 엘라스틱넷
# - 결정트릭
# - SVM
# - 앙상블

# %% [markdown]
# ## 비지도 학습 > 군집

# %% [markdown]
# - K-MEAN(거리 기반)
# - Mean-Shift(밀도 기반)
# - GMM(확률 기반)
# - DBSCAN(밀도 기반 + 기하학 분포)

# %% [markdown]
# ## 비지도 학습 > 차원 축소

# %% [markdown]
# - **PCA**, LDA, SVD, NMF

# %% [markdown]
# # 데이터 준비, 피처 엔지니어링, EDA

# %% [markdown]
# ## 데이터 인코딩

# %% [markdown]
# - LabelEncoder, OrdinalEncoder, OneHotEncoder(압축 사용 가능), ThirdPartEncoder(Category_endocers)

# %% [markdown]
# ## 피처 스케일링

# %% [markdown]
# - 데이터 전체를 조정
#   - StandardScaler(평균 0, 표준편차 1)
#   - MinMaxScaler
#   - ...

# %% [markdown]
# ## 피처 전처리

# %% [markdown]
# - 피처 제거
# - 결측치 처리(피처로 사용? 제거?)
# - 이상치 처리
# - 피처 생성

# %% [markdown]
# ## EDA

# %% [markdown]
# # 학습

# %% [markdown]
# ## 기본 학습

# %% [markdown]
# ## 교차 검증

# %% [markdown]
# - K-폴드
#   - 정답 분포가 균형
# - 층화 K-폴드
#   - 정답 분포가 불균형

# %% [markdown]
# # 예측

# %% [markdown]
# # 성능평가

# %% [markdown]
# ## 분류

# %% [markdown]
# - 오차행렬(혼동행렬)
#   - 정확도, 정밀도, 재현율, F1-Score, ...
#   - ROC, AUC

# %% [markdown]
# ## 회귀

# %% [markdown]
# - 손실함수
#   - mse, rmse, msle, ...

# %% [markdown]
# ## 군집

# %% [markdown]
# # 최적화

# %% [markdown]
# ## 하이퍼 파라미터 튜닝

# %% [markdown]
# - 그리드 서치
# - 랜덤 서치
# - 베이지안 최적

# %% [markdown]
# ## 파이프라인

# %% [markdown]
# ## 서드파트

# %% [markdown]
# - AutoML
#   - 파이캐럿
#   - ...

# %% [markdown]
# # 모델 덤프 및 서빙(인프라 구축, MLOps)
